# %%
CONFIG_ITEM_TEMPLATE = """  {experiment_name}:
    enabled: true
    read_params: 
      file_name: ${{hydra:runtime.cwd}}/data/{experiment_name}_embeddings.pickle
    target_options: {{}}
"""



for pretrain_epoches in range(4, 40, 5):
    epoches_after = 40 - pretrain_epoches -1
    experiment_name = f"check_coles_only__pretrained_epoches_{pretrain_epoches}__coles_gnn_weighted__w_pred__no_gnn_GraphSAGE__no_orig__alpha_0.5__gamma_0.5____lp_criterion_MSELoss__40_epoches__epoches_after_ckpt_{epoches_after}__try_1"
    print(CONFIG_ITEM_TEMPLATE.format(experiment_name=experiment_name))
# Out:
#   check_coles_only__pretrained_epoches_4__coles_gnn_weighted__w_pred__no_gnn_GraphSAGE__no_orig__alpha_0.5__gamma_0.5____lp_criterion_MSELoss__40_epoches__epoches_after_ckpt_35__try_1_embeddings.pickle:
#     enabled: true
#     read_params:
#       file_name: ${hydra:runtime.cwd}/data/check_coles_only__pretrained_epoches_4__coles_gnn_weighted__w_pred__no_gnn_GraphSAGE__no_orig__alpha_0.5__gamma_0.5____lp_criterion_MSELoss__40_epoches__epoches_after_ckpt_35__try_1_embeddings.pickle_embeddings.pickle
#     target_options: {}
#
#   check_coles_only__pretrained_epoches_9__coles_gnn_weighted__w_pred__no_gnn_GraphSAGE__no_orig__alpha_0.5__gamma_0.5____lp_criterion_MSELoss__40_epoches__epoches_after_ckpt_30__try_1_embeddings.pickle:
#     enabled: true
#     read_params:
# ...
